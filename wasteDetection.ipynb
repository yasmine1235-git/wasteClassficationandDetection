# %%
# Clone the dataset from GitHub
# !git clone https://github.com/PUTvision/UAVVaste.git

# Navigate into the dataset directory
# %cd UAVVaste
# Out:
# Cloning into 'UAVVaste'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 81 (delta 36), reused 41 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 427.63 KiB | 639.00 KiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/UAVVaste

# %%
# Install any necessary libraries
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)

# %%
import json
import os
import requests

# Paths
annotations_path = "/content/UAVVaste/annotations/annotations.json"
images_dir = "/content/UAVVaste/images"

# Create images directory if not exists
os.makedirs(images_dir, exist_ok=True)

# Load annotations
with open(annotations_path, "r") as f:
    data = json.load(f)

# Download images
for img_info in data["images"]:
    img_name = img_info["file_name"]
    img_url = img_info["flickr_url"]

    if img_url:  # Check if a URL is provided
        img_path = os.path.join(images_dir, img_name)
        response = requests.get(img_url, stream=True)

        if response.status_code == 200:
            with open(img_path, "wb") as img_file:
                img_file.write(response.content)
            print(f"Downloaded: {img_name}")
        else:
            print(f"Failed to download: {img_name}")

print("All images downloaded successfully!")
# Out:
# Downloaded: BATCH_d07_img_6400.jpg
# Downloaded: BATCH_d07_img_580.jpg
# Downloaded: BATCH_d07_img_2380.jpg
# Downloaded: BATCH_d07_img_880.jpg
# Downloaded: BATCH_d07_img_4550.jpg
# Downloaded: BATCH_d07_img_410.jpg
# Downloaded: BATCH_d07_img_6030.jpg
# Downloaded: BATCH_d07_img_3470.jpg
# Downloaded: BATCH_d07_img_6970.jpg
# Downloaded: BATCH_d07_img_5110.jpg
# Downloaded: BATCH_d07_img_1250.jpg
# Downloaded: BATCH_d07_img_450.jpg
# Downloaded: BATCH_d07_img_2760.jpg
# Downloaded: BATCH_d07_img_2340.jpg
# Downloaded: BATCH_d07_img_610.jpg
# Downloaded: BATCH_d07_img_2080.jpg
# Downloaded: BATCH_d07_img_7260.jpg
# Downloaded: BATCH_d07_img_2930.jpg
# Downloaded: BATCH_d07_img_4370.jpg
# Downloaded: BATCH_d07_img_1760.jpg
# Downloaded: BATCH_d07_img_4730.jpg
# Downloaded: BATCH_d07_img_1700.jpg
# Downloaded: BATCH_d07_img_4670.jpg
# Downloaded: BATCH_d07_img_1390.jpg
# Downloaded: BATCH_d07_img_360.jpg
# Downloaded: BATCH_d07_img_600.jpg
# Downloaded: BATCH_d07_img_1120.jpg
# Downloaded: BATCH_d07_img_510.jpg
# Downloaded: BATCH_d07_img_6520.jpg
# Downloaded: BATCH_d07_img_2670.jpg
# Downloaded: BATCH_d07_img_2500.jpg
# Downloaded: BATCH_d07_img_3010.jpg
# Downloaded: BATCH_d07_img_2820.jpg
# Downloaded: BATCH_d07_img_3330.jpg
# Downloaded: BATCH_d07_img_650.jpg
# Downloaded: BATCH_d07_img_6110.jpg
# Downloaded: BATCH_d07_img_6230.jpg
# Downloaded: BATCH_d07_img_5020.jpg
# Downloaded: BATCH_d07_img_4430.jpg
# Downloaded: BATCH_d08_img_4420.jpg
# Downloaded: BATCH_d08_img_4640.jpg
# Downloaded: BATCH_d08_img_3050.jpg
# Downloaded: BATCH_d08_img_2210.jpg
# Downloaded: BATCH_d08_img_1260.jpg
# Downloaded: BATCH_d08_img_2850.jpg
# Downloaded: BATCH_d08_img_4050.jpg
# Downloaded: BATCH_d08_img_5120.jpg
# Downloaded: BATCH_d08_img_950.jpg
# Downloaded: BATCH_d08_img_1630.jpg
# Downloaded: BATCH_d08_img_990.jpg
# Downloaded: BATCH_d08_img_660.jpg
# Downloaded: BATCH_d08_img_1510.jpg
# Downloaded: BATCH_d08_img_2280.jpg
# Downloaded: BATCH_d08_img_590.jpg
# Downloaded: BATCH_d08_img_390.jpg
# Downloaded: BATCH_d08_img_2500.jpg
# Downloaded: BATCH_d08_img_1210.jpg
# Downloaded: BATCH_d08_img_440.jpg
# Downloaded: BATCH_d08_img_4600.jpg
# Downloaded: BATCH_d08_img_5050.jpg
# Downloaded: BATCH_d08_img_1360.jpg
# Downloaded: BATCH_d08_img_4150.jpg
# Downloaded: BATCH_d08_img_3190.jpg
# Downloaded: BATCH_d08_img_5470.jpg
# Downloaded: BATCH_d08_img_4700.jpg
# Downloaded: BATCH_d08_img_1060.jpg
# All images downloaded successfully!

# %%
import cv2
import numpy as np
import json
from pathlib import Path
from pycocotools.coco import COCO
from tqdm import tqdm

def segmentation_to_bbox(segmentation, img_w, img_h):
    # Segmentation is a list of x, y coordinates for the polygon
    x_coords = segmentation[::2]  # Extract all x coordinates (even indices)
    y_coords = segmentation[1::2]  # Extract all y coordinates (odd indices)

    # Find the minimum and maximum values for x and y to create a bounding box
    xmin = min(x_coords)
    xmax = max(x_coords)
    ymin = min(y_coords)
    ymax = max(y_coords)

    # Calculate the center of the bounding box (normalized)
    center_x = (xmin + xmax) / 2 / img_w
    center_y = (ymin + ymax) / 2 / img_h

    # Calculate the width and height of the bounding box (normalized)
    width = (xmax - xmin) / img_w
    height = (ymax - ymin) / img_h

    return center_x, center_y, width, height

def convert_json_to_yolo_mask(annotation_path: str, images_dir_path: str, dest_path: str, train_val_test: dict):
    dataset = COCO(annotation_path)

    for img_id in tqdm(dataset.imgs):
        img_info = dataset.imgs[img_id]
        img_name = img_info['file_name']
        img_path = Path(images_dir_path) / img_name
        img = cv2.imread(str(img_path))

        # Check if image is loaded correctly
        if img is None:
            print(f"Warning: Couldn't read image {img_name}")
            continue

        img_h, img_w, _ = img.shape

        ann_ids = dataset.getAnnIds(imgIds=img_id)
        anns = dataset.loadAnns(ann_ids)

        # Determine the destination directory based on train/val/test split
        if img_name in train_val_test['train']:
            dest_dir = Path(dest_path) / 'train'
        elif img_name in train_val_test['val']:
            dest_dir = Path(dest_path) / 'val'
        elif img_name in train_val_test['test']:
            dest_dir = Path(dest_path) / 'test'

        dest_dir.mkdir(parents=True, exist_ok=True)

        # Save the image
        cv2.imwrite(str(dest_dir / img_name), img)

        # Create the corresponding YOLO text file
        with open(str(dest_dir / img_name).replace('.jpg', '.txt').replace('.JPG', '.txt').replace('.PNG', '.txt'), 'w') as f:
            for ann in anns:
                row = '0'  # Assuming class_id is 0 for all objects, adjust if needed

                # Use the segmentation_to_bbox function to convert segmentation to bounding box
                bbox = segmentation_to_bbox(ann['segmentation'][0], img_w, img_h)

                # Add the normalized bounding box coordinates to the row
                row += f' {bbox[0]} {bbox[1]} {bbox[2]} {bbox[3]}'

                # Write the row for each object in the image
                row += '\n'
                f.write(row)


if __name__ == '__main__':
    # Update paths here with your specific directories
    annotation_path = '/content/UAVVaste/annotations/annotations.json'  # Path to your annotations file
    images_dir_path = '/content/UAVVaste/images'  # Path to your images directory
    dest_path = '/content/UAVVaste/yolo_annotations/'  # Path where YOLO format files will be saved

    # Load train, val, and test splits
    with open('/content/UAVVaste/annotations/train_val_test_distribution_file.json', 'r') as f:
        train_val_test = json.load(f)

    convert_json_to_yolo_mask(annotation_path, images_dir_path, dest_path, train_val_test)
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 100%|██████████| 772/772 [01:43<00:00,  7.49it/s]

# %%
from pathlib import Path

image_dir = Path('/content/UAVVaste/images/')
missing_images = []

with open('/content/UAVVaste/annotations/train_val_test_distribution_file.json', 'r') as f:
    train_val_test = json.load(f)

all_images = train_val_test['train'] + train_val_test['val'] + train_val_test['test']

for img_name in all_images:
    img_path = image_dir / img_name
    if not img_path.exists():
        missing_images.append(img_name)

print(f"Missing images: {missing_images}")
# Out:
# Missing images: []

# %%
import os
import shutil
from pathlib import Path

def move_files(src_dirs, dest_images_dir, dest_labels_dir):
    # Create destination directories if they don't exist
    Path(dest_images_dir).mkdir(parents=True, exist_ok=True)
    Path(dest_labels_dir).mkdir(parents=True, exist_ok=True)

    # Loop through the source directories (train, test, val)
    for src_dir in src_dirs:
        # Ensure the source directory exists
        if not os.path.exists(src_dir):
            print(f"Warning: {src_dir} doesn't exist. Skipping.")
            continue

        # List all files in the source directory
        for file in os.listdir(src_dir):
            file_path = os.path.join(src_dir, file)

            # If it's an image, move to the 'images' folder
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG')):
                dest_file = os.path.join(dest_images_dir, file)
                shutil.move(file_path, dest_file)
                print(f"Moved image: {file}")

            # If it's a text file, move to the 'labels' folder
            elif file.lower().endswith('.txt'):
                dest_file = os.path.join(dest_labels_dir, file)
                shutil.move(file_path, dest_file)
                print(f"Moved label: {file}")

if __name__ == '__main__':
    # Paths to your source directories (train, val, test)
    src_dirs = [
        '/content/UAVVaste/yolo_annotations/train',
        '/content/UAVVaste/yolo_annotations/val',
        '/content/UAVVaste/yolo_annotations/test'
    ]

    # Destination directories for images and labels
    dest_images_dir = '/content/data/images'
    dest_labels_dir = '/content/data/labels'

    # Move files
    move_files(src_dirs, dest_images_dir, dest_labels_dir)
# Out:
# Moved label: BATCH_s04_img_3460.txt
# Moved image: GOPR0044.JPG
# Moved image: batch_05_img_1540.jpg
# Moved image: BATCH_s05_img_210.jpg
# Moved label: BATCH_d07_img_2340.txt
# Moved image: batch_s02_img_150.jpg
# Moved image: BATCH_d06_img_2260.jpg
# Moved image: BATCH_s04_img_3600.jpg
# Moved image: BATCH_d08_img_5300.jpg
# Moved label: batch_s02_img_16.txt
# Moved image: BATCH_s05_img_1940.jpg
# Moved label: GOPR0041.txt
# Moved label: batch_04_img_1780.txt
# Moved label: BATCH_d06_img_3280.txt
# Moved image: BATCH_s03_img_2080.jpg
# Moved image: batch_s02_img_120.jpg
# Moved label: BATCH_d06_img_2260.txt
# Moved image: batch_s02_img_89.jpg
# Moved image: batch_05_img_1820.jpg
# Moved image: BATCH_d06_img_2840.jpg
# Moved image: batch_02_img_320.jpg
# Moved image: batch_s01_img_2740.jpg
# Moved image: batch_03_img_3740.jpg
# Moved image: BATCH_d07_img_5710.jpg
# Moved image: batch_s02_img_12.jpg
# Moved image: BATCH_d07_img_2670.jpg
# Moved image: BATCH_d07_img_720.jpg
# Moved image: BATCH_d07_img_810.jpg
# Moved image: BATCH_d07_img_1610.jpg
# Moved label: batch_s02_img_41.txt
# Moved label: batch_s01_img_860.txt
# Moved label: batch_s02_img_69.txt
# Moved image: GOPR0050.JPG
# Moved image: photo_2020-10-23_14-02-02.jpg
# Moved image: batch_s02_img_99.jpg
# Moved label: batch_04_img_2780.txt
# Moved image: batch_03_img_720.jpg
# Moved label: BATCH_s03_img_840.txt
# Moved image: batch_04_img_3320.jpg
# Moved label: BATCH_d07_img_5900.txt
# Moved label: BATCH_s04_img_2920.txt
# Moved image: batch_03_img_3160.jpg
# Moved label: batch_01_frame_26.txt
# Moved label: BATCH_s05_img_510.txt
# Moved image: BATCH_d06_img_1750.jpg
# Moved image: BATCH_d07_img_950.jpg
# Moved image: BATCH_s05_img_9690.jpg
# Moved label: batch_s02_img_155.txt
# Moved label: batch_s01_img_1700.txt
# Moved image: BATCH_d08_img_2890.jpg
# Moved image: BATCH_d06_img_1270.jpg
# Moved label: BATCH_d06_img_920.txt
# Moved image: batch_04_img_1640.jpg
# Moved label: BATCH_d07_img_4970.txt
# Moved label: BATCH_d08_img_1630.txt
# Moved image: batch_s02_img_81.jpg
# Moved label: batch_04_img_4180.txt
# Moved image: batch_s02_img_30.jpg
# Moved image: BATCH_s04_img_7860.jpg
# Moved label: batch_s02_img_116.txt
# Moved label: batch_s02_img_92.txt
# Moved image: BATCH_s04_img_5760.jpg
# Moved label: BATCH_s03_img_2160.txt
# Moved image: BATCH_s04_img_4720.jpg
# Moved image: BATCH_s03_img_2160.jpg
# Moved image: BATCH_s05_img_1610.jpg
# Moved label: BATCH_s03_img_3340.txt
# Moved label: batch_05_img_5540.txt
# Moved image: GOPR0040.JPG
# Moved label: batch_s02_img_32.txt
# Moved image: BATCH_d08_img_2850.jpg
# Moved label: batch_s02_img_139.txt
# Moved image: batch_s02_img_63.jpg
# Moved image: batch_s02_img_136.jpg
# Moved image: BATCH_d06_img_3180.jpg
# Moved image: BATCH_s03_img_3420.jpg
# Moved label: BATCH_d06_img_380.txt
# Moved label: batch_04_img_4660.txt
# Moved label: batch_04_img_2300.txt
# Moved label: GOPR0026.txt
# Moved image: BATCH_d08_img_3950.jpg
# Moved image: BATCH_d07_img_610.jpg
# Moved image: BATCH_s05_img_9010.jpg
# Moved image: BATCH_s03_img_4300.jpg
# Moved label: GOPR0021.txt
# Moved label: BATCH_s03_img_440.txt
# Moved image: BATCH_d07_img_1760.jpg
# Moved image: batch_s02_img_131.jpg
# Moved label: BATCH_d07_img_1500.txt
# Moved image: batch_s01_img_1160.jpg
# Moved label: batch_s02_img_83.txt
# Moved image: BATCH_s05_img_20.jpg
# Moved image: batch_01_frame_10.jpg
# Moved image: BATCH_d06_img_3280.jpg
# Moved image: photo_2020-10-23_14-02-00.jpg
# Moved image: BATCH_d08_img_1420.jpg
# Moved label: batch_04_img_1260.txt
# Moved image: batch_04_img_3600.jpg
# Moved label: BATCH_s04_img_7080.txt
# Moved image: BATCH_d08_img_590.jpg
# Moved label: BATCH_s05_img_5230.txt
# Moved label: batch_s02_img_145.txt
# Moved label: batch_s02_img_100.txt
# Moved label: batch_s01_img_2220.txt
# Moved label: BATCH_d07_img_720.txt
# Moved image: batch_s02_img_91.jpg
# Moved image: batch_05_img_1340.jpg
# Moved image: batch_s02_img_4.jpg
# Moved label: BATCH_d07_img_2520.txt
# Moved label: batch_s02_img_108.txt
# Moved label: BATCH_s04_img_1000.txt
# Moved label: BATCH_d08_img_4220.txt
# Moved image: batch_s02_img_116.jpg
# Moved label: BATCH_s04_img_6100.txt
# Moved image: BATCH_d07_img_450.jpg
# Moved label: batch_s02_img_152.txt
# Moved image: batch_04_img_4180.jpg
# Moved image: BATCH_d07_img_5380.jpg
# Moved image: BATCH_s05_img_9470.jpg
# Moved image: batch_01_frame_23.jpg
# Moved image: BATCH_s03_img_640.jpg
# Moved image: BATCH_d08_img_5050.jpg
# Moved label: batch_04_img_2420.txt
# Moved image: batch_04_img_720.jpg
# Moved image: BATCH_s04_img_5460.jpg
# Moved label: batch_03_img_3160.txt
# Moved image: BATCH_s04_img_3760.jpg
# Moved label: batch_s02_img_84.txt
# Moved label: batch_04_img_3760.txt
# Moved label: BATCH_d07_img_2820.txt
# Moved label: batch_05_img_5080.txt
# Moved label: BATCH_d08_img_1510.txt
# Moved label: batch_s02_img_9.txt
# Moved image: BATCH_d07_img_4920.jpg
# Moved label: BATCH_d07_img_4480.txt
# Moved label: BATCH_d06_img_2540.txt
# Moved image: batch_s02_img_132.jpg
# Moved label: BATCH_d06_img_2840.txt
# Moved label: batch_02_img_3500.txt
# Moved label: batch_02_img_2700.txt
# Moved image: BATCH_s04_img_9900.jpg
# Moved image: BATCH_d08_img_4290.jpg
# Moved image: BATCH_d07_img_2760.jpg
# Moved image: batch_s02_img_85.jpg
# Moved label: BATCH_d07_img_1550.txt
# Moved label: batch_04_img_3600.txt
# Moved image: BATCH_d08_img_4640.jpg
# Moved image: batch_s02_img_2.jpg
# Moved label: BATCH_s05_img_1960.txt
# Moved image: BATCH_d06_img_1050.jpg
# Moved image: batch_01_frame_34.jpg
# Moved image: BATCH_s04_img_6460.jpg
# Moved image: BATCH_d06_img_270.jpg
# Moved image: batch_05_img_2360.jpg
# Moved image: batch_02_img_1400.jpg
# Moved label: GOPR0034.txt
# Moved image: BATCH_d08_img_1260.jpg
# Moved label: BATCH_s05_img_1230.txt
# Moved label: batch_s02_img_80.txt
# Moved image: batch_05_img_780.jpg
# Moved label: BATCH_d06_img_270.txt
# Moved image: batch_s01_img_680.jpg
# Moved image: batch_04_img_2900.jpg
# Moved image: GOPR0022.JPG
# Moved label: BATCH_d07_img_2270.txt
# Moved label: BATCH_s03_img_3640.txt
# Moved image: BATCH_d07_img_1500.jpg
# Moved label: photo_2020-10-23_14-02-00.txt
# Moved image: GOPR0053.JPG
# Moved label: batch_s02_img_141.txt
# Moved image: batch_s02_img_78.jpg
# Moved image: GOPR0025.JPG
# Moved image: BATCH_d07_img_7260.jpg
# Moved image: batch_04_img_1120.jpg
# Moved label: batch_s02_img_6.txt
# Moved label: batch_s01_img_1060.txt
# Moved label: BATCH_s05_img_9690.txt
# Moved image: batch_s02_img_74.jpg
# Moved image: BATCH_s05_img_7690.jpg
# Moved image: BATCH_s04_img_7380.jpg
# Moved image: BATCH_d08_img_4220.jpg
# Moved image: BATCH_d07_img_2340.jpg
# Moved label: BATCH_d07_img_5710.txt
# Moved image: BATCH_d07_img_5400.jpg
# Moved label: batch_s01_img_1660.txt
# Moved label: BATCH_s04_img_3540.txt
# Moved label: batch_02_img_360.txt
# Moved label: batch_s01_img_1760.txt
# Moved image: batch_04_img_2860.jpg
# Moved image: BATCH_d07_img_6020.jpg
# Moved image: photo_2020-10-23_14-02-04.jpg
# Moved label: batch_02_img_340.txt
# Moved label: BATCH_s03_img_4220.txt
# Moved label: batch_05_img_1780.txt
# Moved label: BATCH_d06_img_3180.txt
# Moved image: batch_s02_img_76.jpg
# Moved label: batch_02_img_3580.txt
# Moved image: batch_s01_img_1920.jpg
# Moved label: batch_s02_img_65.txt
# Moved image: BATCH_d08_img_1630.jpg
# Moved image: batch_05_img_4180.jpg
# Moved image: batch_03_img_2180.jpg
# Moved label: batch_s02_img_143.txt
# Moved image: batch_s01_img_800.jpg
# Moved image: batch_03_img_3660.jpg
# Moved label: BATCH_s05_img_7460.txt
# Moved image: BATCH_d08_img_5400.jpg
# Moved image: BATCH_s04_img_6500.jpg
# Moved image: BATCH_s03_img_3540.jpg
# Moved label: batch_03_img_3660.txt
# Moved image: batch_02_img_720.jpg
# Moved image: batch_02_img_520.jpg
# Moved image: batch_s01_img_2980.jpg
# Moved image: BATCH_s04_img_7500.jpg
# Moved label: BATCH_s04_img_7220.txt
# Moved image: batch_05_img_4840.jpg
# Moved image: batch_s02_img_65.jpg
# Moved image: BATCH_s05_img_5590.jpg
# Moved label: batch_05_img_960.txt
# Moved image: BATCH_s05_img_9400.jpg
# Moved label: BATCH_s05_img_9010.txt
# Moved label: batch_01_frame_10.txt
# Moved label: BATCH_d08_img_660.txt
# Moved image: BATCH_s05_img_5990.jpg
# Moved label: batch_02_img_3820.txt
# Moved image: batch_s02_img_64.jpg
# Moved image: batch_02_img_340.jpg
# Moved label: batch_05_img_840.txt
# Moved label: BATCH_d06_img_1050.txt
# Moved label: batch_03_img_600.txt
# Moved image: BATCH_s04_img_7220.jpg
# Moved label: DJI_0009.txt
# Moved image: BATCH_d06_img_920.jpg
# Moved image: BATCH_s03_img_3360.jpg
# Moved label: batch_s02_img_96.txt
# Moved image: BATCH_d07_img_510.jpg
# Moved image: batch_s02_img_82.jpg
# Moved label: batch_s02_img_114.txt
# Moved image: GOPR0024.JPG
# Moved label: BATCH_d08_img_1060.txt
# Moved label: batch_s01_img_1240.txt
# Moved label: batch_01_frame_35.txt
# Moved image: BATCH_d06_img_1580.jpg
# Moved image: batch_04_img_4140.jpg
# Moved image: BATCH_d07_img_1010.jpg
# Moved image: BATCH_d07_img_7030.jpg
# Moved label: BATCH_d07_img_460.txt
# Moved image: BATCH_d07_img_6520.jpg
# Moved image: BATCH_d08_img_5040.jpg
# Moved label: BATCH_s04_img_2640.txt
# Moved label: BATCH_d07_img_3990.txt
# Moved label: BATCH_d08_img_4850.txt
# Moved label: batch_s02_img_20.txt
# Moved label: BATCH_s04_img_6640.txt
# Moved image: batch_04_img_1140.jpg
# Moved label: BATCH_s05_img_9470.txt
# Moved label: BATCH_s04_img_4800.txt
# Moved image: batch_s01_img_1700.jpg
# Moved image: BATCH_d08_img_3130.jpg
# Moved label: BATCH_d08_img_1260.txt
# Moved image: BATCH_d07_img_1330.jpg
# Moved label: GOPR0045.txt
# Moved label: BATCH_d07_img_7260.txt
# Moved label: BATCH_d06_img_1660.txt
# Moved label: BATCH_s04_img_7380.txt
# Moved label: BATCH_d08_img_1590.txt
# Moved label: BATCH_s03_img_1160.txt
# Moved image: BATCH_d07_img_1450.jpg
# Moved label: batch_s02_img_76.txt
# Moved label: camera_img_0.txt
# Moved image: camera_img_0.jpg
# Moved image: BATCH_d07_img_5470.jpg
# Moved image: batch_02_img_2540.jpg
# Moved label: batch_s02_img_30.txt
# Moved label: batch_s02_img_11.txt
# Moved image: BATCH_d08_img_3050.jpg
# Moved image: batch_s02_img_127.jpg
# Moved label: photo_2020-10-23_14-02-03.txt
# Moved label: BATCH_s03_img_4160.txt
# Moved image: BATCH_s04_img_7240.jpg
# Moved label: batch_01_frame_11.txt
# Moved label: batch_02_img_1960.txt
# Moved image: batch_s02_img_16.jpg
# Moved label: BATCH_s04_img_5900.txt
# Moved label: BATCH_d06_img_0.txt
# Moved image: BATCH_d07_img_6970.jpg
# Moved label: batch_s02_img_81.txt
# Moved image: batch_01_frame_35.jpg
# Moved label: batch_s02_img_131.txt
# Moved image: BATCH_s03_img_440.jpg
# Moved label: GOPR0019.txt
# Moved image: batch_01_frame_7.jpg
# Moved label: BATCH_d08_img_1030.txt
# Moved image: batch_04_img_1820.jpg
# Moved image: batch_02_img_1960.jpg
# Moved label: batch_01_frame_20.txt
# Moved image: batch_04_img_1620.jpg
# Moved label: batch_05_img_4180.txt
# Moved image: batch_s02_img_11.jpg
# Moved label: batch_05_img_780.txt
# Moved image: BATCH_d08_img_390.jpg
# Moved label: BATCH_d07_img_510.txt
# Moved label: batch_05_img_1500.txt
# Moved image: GOPR0048.JPG
# Moved image: batch_03_img_2720.jpg
# Moved image: BATCH_d07_img_1700.jpg
# Moved image: batch_04_img_2420.jpg
# Moved label: batch_05_img_2360.txt
# Moved label: BATCH_d08_img_4700.txt
# Moved label: BATCH_s05_img_7940.txt
# Moved image: BATCH_d07_img_5960.jpg
# Moved label: batch_01_frame_19.txt
# Moved label: batch_01_frame_27.txt
# Moved label: BATCH_d06_img_1140.txt
# Moved image: batch_s02_img_36.jpg
# Moved label: batch_01_frame_15.txt
# Moved label: BATCH_d07_img_6320.txt
# Moved label: batch_05_img_1540.txt
# Moved label: batch_s02_img_74.txt
# Moved label: batch_s02_img_115.txt
# Moved image: photo_2020-10-23_14-02-03.jpg
# Moved label: batch_s02_img_78.txt
# Moved image: batch_s02_img_71.jpg
# Moved label: BATCH_s04_img_3040.txt
# Moved image: batch_01_frame_1.jpg
# Moved label: batch_s02_img_128.txt
# Moved image: BATCH_s04_img_3460.jpg
# Moved label: BATCH_d07_img_5110.txt
# Moved label: BATCH_d08_img_1360.txt
# Moved label: batch_02_img_3780.txt
# Moved image: BATCH_s03_img_2800.jpg
# Moved label: batch_s02_img_94.txt
# Moved label: BATCH_d07_img_4720.txt
# Moved image: BATCH_s05_img_6580.jpg
# Moved label: BATCH_d07_img_3470.txt
# Moved label: BATCH_d08_img_3130.txt
# Moved label: batch_s02_img_129.txt
# Moved image: batch_05_img_960.jpg
# Moved image: BATCH_s04_img_9440.jpg
# Moved image: BATCH_d08_img_4850.jpg
# Moved label: batch_s02_img_44.txt
# Moved image: batch_02_img_3260.jpg
# Moved image: BATCH_d07_img_410.jpg
# Moved label: batch_s02_img_112.txt
# Moved label: batch_01_frame_1.txt
# Moved label: BATCH_d07_img_1760.txt
# Moved label: BATCH_s04_img_8600.txt
# Moved label: GOPR0022.txt
# Moved image: batch_s02_img_83.jpg
# Moved image: batch_s02_img_34.jpg
# Moved label: BATCH_s05_img_5590.txt
# Moved image: DJI_0010.JPG
# Moved image: batch_04_img_3760.jpg
# Moved image: BATCH_s04_img_6200.jpg
# Moved image: batch_s02_img_118.jpg
# Moved label: BATCH_d08_img_3050.txt
# Moved label: BATCH_s03_img_1880.txt
# Moved label: BATCH_d07_img_810.txt
# Moved label: BATCH_s04_img_4720.txt
# Moved image: batch_s02_img_79.jpg
# Moved label: batch_s02_img_60.txt
# Moved label: BATCH_d06_img_200.txt
# Moved label: batch_s02_img_8.txt
# Moved image: batch_05_img_600.jpg
# Moved label: batch_05_img_260.txt
# Moved image: batch_01_frame_9.jpg
# Moved image: batch_01_frame_26.jpg
# Moved image: batch_s02_img_87.jpg
# Moved image: BATCH_s03_img_1880.jpg
# Moved image: BATCH_d07_img_2220.jpg
# Moved image: batch_s02_img_44.jpg
# Moved label: BATCH_d07_img_880.txt
# Moved label: BATCH_d07_img_1250.txt
# Moved label: BATCH_s03_img_4300.txt
# Moved label: BATCH_s04_img_5460.txt
# Moved image: batch_05_img_1980.jpg
# Moved label: BATCH_s05_img_210.txt
# Moved label: batch_01_frame_17.txt
# Moved label: BATCH_d08_img_4520.txt
# Moved label: BATCH_s05_img_7690.txt
# Moved image: BATCH_d08_img_5120.jpg
# Moved image: BATCH_d08_img_4600.jpg
# Moved image: BATCH_s04_img_4160.jpg
# Moved label: batch_05_img_1240.txt
# Moved image: BATCH_d07_img_2270.jpg
# Moved image: batch_s02_img_154.jpg
# Moved label: batch_03_img_2180.txt
# Moved label: batch_s02_img_33.txt
# Moved image: batch_04_img_980.jpg
# Moved label: batch_04_img_140.txt
# Moved image: batch_s02_img_59.jpg
# Moved image: BATCH_d07_img_6230.jpg
# Moved label: BATCH_s04_img_5760.txt
# Moved label: BATCH_d07_img_7030.txt
# Moved label: batch_s02_img_120.txt
# Moved label: BATCH_s03_img_1320.txt
# Moved label: batch_s01_img_2960.txt
# Moved image: batch_04_img_1940.jpg
# Moved image: BATCH_s05_img_7460.jpg
# Moved image: BATCH_d07_img_6030.jpg
# Moved label: BATCH_s04_img_7960.txt
# Moved label: BATCH_d08_img_2500.txt
# Moved image: batch_s02_img_135.jpg
# Moved label: BATCH_s03_img_3360.txt
# Moved image: batch_s01_img_1060.jpg
# Moved image: GOPR0034.JPG
# Moved label: batch_01_frame_0.txt
# Moved image: BATCH_d08_img_2500.jpg
# Moved label: batch_01_frame_24.txt
# Moved label: BATCH_s03_img_300.txt
# Moved image: BATCH_d06_img_380.jpg
# Moved label: batch_01_frame_32.txt
# Moved label: batch_s01_img_2880.txt
# Moved label: BATCH_s04_img_9900.txt
# Moved label: batch_02_img_1400.txt
# Moved image: batch_s02_img_108.jpg
# Moved label: batch_s02_img_77.txt
# Moved image: BATCH_d07_img_2520.jpg
# Moved image: batch_s02_img_92.jpg
# Moved label: BATCH_d07_img_1450.txt
# Moved image: batch_s02_img_54.jpg
# Moved image: batch_04_img_840.jpg
# Moved label: BATCH_s03_img_640.txt
# Moved label: BATCH_s04_img_6060.txt
# Moved label: batch_01_frame_29.txt
# Moved image: batch_s02_img_146.jpg
# Moved label: batch_s02_img_113.txt
# Moved image: batch_05_img_6080.jpg
# Moved label: BATCH_s05_img_8950.txt
# Moved label: batch_05_img_2140.txt
# Moved image: batch_s01_img_1760.jpg
# Moved label: BATCH_s04_img_9600.txt
# Moved label: BATCH_d08_img_950.txt
# Moved label: batch_01_frame_31.txt
# Moved image: BATCH_d07_img_2960.jpg
# Moved image: batch_s01_img_620.jpg
# Moved label: BATCH_d07_img_5470.txt
# Moved label: batch_02_img_2000.txt
# Moved label: batch_01_frame_25.txt
# Moved label: BATCH_d07_img_6970.txt
# Moved image: batch_02_img_960.jpg
# Moved label: batch_s02_img_146.txt
# Moved label: batch_s02_img_142.txt
# Moved label: batch_02_img_3160.txt
# Moved image: BATCH_d07_img_4730.jpg
# Moved label: batch_s01_img_2740.txt
# Moved label: batch_s01_img_1920.txt
# Moved label: batch_s02_img_56.txt
# Moved image: BATCH_d07_img_4760.jpg
# Moved image: batch_s02_img_134.jpg
# Moved image: batch_03_img_3120.jpg
# Moved label: batch_s02_img_156.txt
# Moved label: BATCH_s04_img_5600.txt
# Moved label: batch_s02_img_126.txt
# Moved image: batch_s02_img_56.jpg
# Moved label: batch_s02_img_125.txt
# Moved image: batch_s02_img_112.jpg
# Moved image: BATCH_d08_img_660.jpg
# Moved label: GOPR0038.txt
# Moved label: batch_02_img_2540.txt
# Moved image: batch_05_img_1240.jpg
# Moved label: photo_2020-10-23_14-02-02.txt
# Moved label: BATCH_s05_img_11130.txt
# Moved label: BATCH_s05_img_9400.txt
# Moved label: batch_01_frame_9.txt
# Moved image: batch_02_img_2620.jpg
# Moved label: BATCH_d06_img_2940.txt
# Moved image: batch_02_img_2440.jpg
# Moved label: BATCH_s04_img_7860.txt
# Moved label: GOPR0054.txt
# Moved image: BATCH_d06_img_3340.jpg
# Moved image: BATCH_s03_img_3700.jpg
# Moved label: batch_04_img_1140.txt
# Moved label: batch_s02_img_111.txt
# Moved image: batch_02_img_2800.jpg
# Moved label: batch_04_img_1940.txt
# Moved image: batch_s02_img_142.jpg
# Moved image: BATCH_d08_img_4420.jpg
# Moved label: BATCH_d07_img_1610.txt
# Moved label: BATCH_s05_img_3960.txt
# Moved label: batch_s02_img_48.txt
# Moved image: BATCH_s03_img_2200.jpg
# Moved image: batch_05_img_3040.jpg
# Moved image: BATCH_s04_img_6120.jpg
# Moved image: batch_02_img_2700.jpg
# Moved image: GOPR0041.JPG
# Moved label: BATCH_d08_img_1420.txt
# Moved image: batch_s02_img_23.jpg
# Moved label: BATCH_d07_img_5960.txt
# Moved label: BATCH_s03_img_2300.txt
# Moved label: BATCH_s05_img_2080.txt
# Moved image: batch_s02_img_94.jpg
# Moved image: batch_s02_img_125.jpg
# Moved image: BATCH_d06_img_1140.jpg
# Moved image: batch_s01_img_2880.jpg
# Moved image: BATCH_d07_img_4970.jpg
# Moved image: BATCH_s05_img_3960.jpg
# Moved image: BATCH_d07_img_600.jpg
# Moved label: batch_02_img_2620.txt
# Moved label: BATCH_d08_img_2890.txt
# Moved label: batch_s02_img_138.txt
# Moved image: batch_s01_img_1240.jpg
# Moved image: batch_s02_img_107.jpg
# Moved image: batch_02_img_1460.jpg
# Moved image: batch_s01_img_2580.jpg
# Moved image: batch_s02_img_129.jpg
# Moved image: BATCH_d07_img_460.jpg
# Moved image: BATCH_s03_img_1160.jpg
# Moved image: BATCH_d07_img_1830.jpg
# Moved image: BATCH_d07_img_1550.jpg
# Moved label: BATCH_d06_img_3360.txt
# Moved label: BATCH_s05_img_9220.txt
# Moved image: batch_s02_img_103.jpg
# Moved label: batch_04_img_4300.txt
# Moved label: BATCH_d07_img_4920.txt
# Moved image: BATCH_s04_img_7320.jpg
# Moved image: batch_s02_img_31.jpg
# Moved label: batch_s02_img_7.txt
# Moved label: batch_01_frame_22.txt
# Moved image: BATCH_d07_img_4370.jpg
# Moved image: batch_05_img_5080.jpg
# Moved image: BATCH_d08_img_1360.jpg
# Moved label: BATCH_s04_img_6600.txt
# Moved label: BATCH_d08_img_590.txt
# Moved image: BATCH_d07_img_1250.jpg
# Moved image: batch_04_img_4080.jpg
# Moved image: batch_s02_img_100.jpg
# Moved image: BATCH_s04_img_6300.jpg
# Moved image: BATCH_d07_img_3170.jpg
# Moved image: BATCH_s04_img_3040.jpg
# Moved label: BATCH_s04_img_6200.txt
# Moved image: batch_01_frame_24.jpg
# Moved label: batch_s01_img_1160.txt
# Moved label: batch_05_img_3580.txt
# Moved label: batch_05_img_600.txt
# Moved label: BATCH_d07_img_6030.txt
# Moved label: batch_s01_img_2720.txt
# Moved label: batch_s02_img_5.txt
# Moved image: batch_04_img_2020.jpg
# Moved image: BATCH_s04_img_7960.jpg
# Moved image: batch_05_img_1780.jpg
# Moved image: batch_04_img_140.jpg
# Moved image: batch_s02_img_69.jpg
# Moved label: BATCH_s05_img_1940.txt
# Moved label: BATCH_s03_img_1400.txt
# Moved label: BATCH_d07_img_4430.txt
# Moved image: batch_s02_img_13.jpg
# Moved image: BATCH_s03_img_3920.jpg
# Moved image: batch_s02_img_126.jpg
# Moved label: BATCH_s03_img_3420.txt
# Moved image: batch_02_img_1320.jpg
# Moved image: BATCH_s04_img_1000.jpg
# Moved image: batch_s02_img_114.jpg
# Moved label: BATCH_d07_img_6520.txt
# Moved label: BATCH_d07_img_1120.txt
# Moved label: BATCH_d07_img_1160.txt
# Moved label: batch_05_img_1340.txt
# Moved label: BATCH_d08_img_2850.txt
# Moved label: BATCH_s04_img_7500.txt
# Moved label: BATCH_d06_img_1580.txt
# Moved image: batch_s02_img_102.jpg
# Moved image: batch_s02_img_60.jpg
# Moved image: GOPR0020.JPG
# Moved label: BATCH_s03_img_3920.txt
# Moved image: batch_s02_img_90.jpg
# Moved label: batch_s01_img_800.txt
# Moved label: batch_02_img_180.txt
# Moved label: batch_s02_img_3.txt
# Moved label: GOPR0056.txt
# Moved label: batch_s01_img_2780.txt
# Moved image: BATCH_d06_img_3100.jpg
# Moved image: GOPR0036.JPG
# Moved label: BATCH_s04_img_7320.txt
# Moved label: batch_s02_img_93.txt
# Moved image: batch_03_img_1920.jpg
# Moved label: batch_05_img_5760.txt
# Moved label: batch_02_img_320.txt
# Moved label: BATCH_d08_img_390.txt
# Moved label: batch_02_img_1140.txt
# Moved label: BATCH_s03_img_2800.txt
# Moved image: batch_s02_img_80.jpg
# Moved image: batch_02_img_3780.jpg
# Moved image: BATCH_s03_img_3780.jpg
# Moved label: GOPR0024.txt
# Moved image: BATCH_s05_img_3500.jpg
# Moved label: BATCH_s04_img_6300.txt
# Moved image: BATCH_d06_img_2360.jpg
# Moved label: BATCH_d07_img_3170.txt
# Moved image: BATCH_s04_img_2640.jpg
# Moved label: BATCH_d07_img_3860.txt
# Moved image: BATCH_s05_img_3520.jpg
# Moved label: BATCH_s03_img_1000.txt
# Moved image: BATCH_d07_img_5020.jpg
# Moved image: batch_s02_img_22.jpg
# Moved label: BATCH_d07_img_3330.txt
# Moved image: batch_s02_img_93.jpg
# Moved image: batch_s02_img_14.jpg
# Moved image: BATCH_s05_img_1960.jpg
# Moved image: BATCH_d07_img_1390.jpg
# Moved image: GOPR0026.JPG
# Moved image: BATCH_s05_img_8950.jpg
# Moved image: batch_s02_img_66.jpg
# Moved image: BATCH_s05_img_7260.jpg
# Moved image: batch_s02_img_156.jpg
# Moved image: batch_s01_img_2960.jpg
# Moved label: BATCH_d07_img_2960.txt
# Moved image: batch_02_img_3400.jpg
# Moved label: batch_s02_img_64.txt
# Moved image: batch_s02_img_139.jpg
# Moved label: BATCH_s03_img_3700.txt
# Moved image: batch_05_img_2140.jpg
# Moved label: BATCH_d07_img_2220.txt
# Moved image: BATCH_d06_img_2940.jpg
# Moved label: BATCH_s04_img_6460.txt
# Moved image: BATCH_s03_img_4160.jpg
# Moved image: batch_02_img_980.jpg
# Moved label: batch_01_frame_34.txt
# Moved label: batch_05_img_6080.txt
# Moved label: BATCH_d07_img_6800.txt
# Moved image: batch_04_img_1180.jpg
# Moved image: batch_s02_img_140.jpg
# Moved image: BATCH_d06_img_2540.jpg
# Moved image: BATCH_s05_img_5740.jpg
# Moved label: batch_s02_img_75.txt
# Moved image: batch_03_img_660.jpg
# Moved label: batch_s02_img_2.txt
# Moved image: batch_s02_img_73.jpg
# Moved image: BATCH_s05_img_8470.jpg
# Moved label: batch_s02_img_54.txt
# Moved label: batch_02_img_720.txt
# Moved label: batch_s01_img_2980.txt
# Moved image: BATCH_d08_img_950.jpg
# Moved label: BATCH_s03_img_2080.txt
# Moved label: BATCH_s05_img_8470.txt
# Moved image: BATCH_d08_img_2580.jpg
# Moved image: GOPR0033.JPG
# Moved label: BATCH_d07_img_1700.txt
# Moved image: batch_s01_img_460.jpg
# Moved image: DJI_0009.JPG
# Moved image: BATCH_d07_img_4550.jpg
# Moved label: BATCH_s03_img_2200.txt
# Moved label: BATCH_d08_img_4290.txt
# Moved label: batch_s01_img_1320.txt
# Moved label: batch_s02_img_52.txt
# Moved label: BATCH_s05_img_1610.txt
# Moved label: BATCH_d08_img_4600.txt
# Moved image: batch_s02_img_143.jpg
# Moved label: BATCH_d08_img_5040.txt
# Moved label: BATCH_d06_img_3100.txt
# Moved label: batch_s01_img_2440.txt
# Moved label: BATCH_d07_img_1330.txt
# Moved image: BATCH_s04_img_2920.jpg
# Moved image: batch_01_frame_32.jpg
# Moved label: batch_s02_img_102.txt
# Moved image: batch_s02_img_58.jpg
# Moved label: BATCH_d07_img_4550.txt
# Moved label: batch_04_img_4340.txt
# Moved image: batch_02_img_3160.jpg
# Moved label: batch_s02_img_82.txt
# Moved image: batch_s02_img_45.jpg
# Moved label: BATCH_d06_img_830.txt
# Moved label: batch_02_img_2500.txt
# Moved label: batch_s02_img_63.txt
# Moved label: batch_s02_img_23.txt
# Moved label: BATCH_d07_img_4370.txt
# Moved label: batch_05_img_1600.txt
# Moved label: BATCH_s03_img_1640.txt
# Moved image: BATCH_d08_img_820.jpg
# Moved label: batch_02_img_520.txt
# Moved image: batch_04_img_4620.jpg
# Moved image: batch_s02_img_155.jpg
# Moved image: batch_03_img_2160.jpg
# Moved image: GOPR0045.JPG
# Moved label: GOPR0020.txt
# Moved label: BATCH_d07_img_4310.txt
# Moved image: batch_s01_img_2720.jpg
# Moved label: BATCH_d08_img_1300.txt
# Moved label: batch_04_img_2860.txt
# Moved label: batch_04_img_1120.txt
# Moved label: batch_01_frame_7.txt
# Moved image: batch_01_frame_18.jpg
# Moved label: BATCH_d07_img_450.txt
# Moved label: batch_02_img_3260.txt
# Moved image: BATCH_d08_img_1030.jpg
# Moved label: BATCH_s04_img_2960.txt
# Moved image: BATCH_s04_img_6100.jpg
# Moved label: GOPR0048.txt
# Moved image: BATCH_s04_img_2960.jpg
# Moved label: batch_04_img_3800.txt
# Moved image: batch_04_img_3800.jpg
# Moved label: GOPR0025.txt
# Moved label: BATCH_d07_img_950.txt
# Moved image: BATCH_s04_img_7080.jpg
# Moved label: batch_04_img_1020.txt
# Moved label: BATCH_s03_img_3780.txt
# Moved image: BATCH_s04_img_6600.jpg
# Moved image: batch_04_img_2240.jpg
# Moved image: BATCH_s04_img_7660.jpg
# Moved image: BATCH_d06_img_830.jpg
# Moved image: BATCH_s04_img_6640.jpg
# Moved image: BATCH_d06_img_200.jpg
# Moved label: BATCH_d07_img_4880.txt
# Moved image: batch_s02_img_19.jpg
# Moved label: BATCH_s04_img_6500.txt
# Moved label: batch_04_img_4140.txt
# Moved image: BATCH_d06_img_3360.jpg
# Moved image: batch_s02_img_95.jpg
# Moved image: batch_s02_img_96.jpg
# Moved label: batch_04_img_1820.txt
# Moved image: BATCH_d07_img_3330.jpg
# Moved image: BATCH_d08_img_4520.jpg
# Moved image: batch_05_img_5760.jpg
# Moved label: BATCH_d08_img_2580.txt
# Moved image: BATCH_d07_img_1650.jpg
# Moved image: BATCH_d07_img_4310.jpg
# Moved label: BATCH_d08_img_4640.txt
# Moved image: batch_04_img_2080.jpg
# Moved label: batch_05_img_820.txt
# Moved label: batch_02_img_1460.txt
# Moved image: batch_s02_img_5.jpg
# Moved image: BATCH_d07_img_4480.jpg
# Moved image: batch_s01_img_1320.jpg
# Moved image: batch_01_frame_22.jpg
# Moved label: BATCH_s05_img_3940.txt
# Moved label: BATCH_d07_img_1830.txt
# Moved label: batch_s02_img_19.txt
# Moved label: batch_s02_img_97.txt
# Moved label: GOPR0055.txt
# Moved label: BATCH_d07_img_1010.txt
# Moved image: batch_02_img_1680.jpg
# Moved image: BATCH_s04_img_8600.jpg
# Moved image: BATCH_d07_img_6320.jpg
# Moved image: BATCH_d07_img_2500.jpg
# Moved image: batch_04_img_1400.jpg
# Moved label: BATCH_d08_img_4070.txt
# Moved label: GOPR0040.txt
# Moved image: batch_02_img_2500.jpg
# Moved label: batch_s02_img_150.txt
# Moved label: batch_02_img_20.txt
# Moved image: BATCH_s04_img_8280.jpg
# Moved label: BATCH_s05_img_20.txt
# Moved image: batch_s02_img_149.jpg
# Moved label: BATCH_s05_img_11050.txt
# Moved label: batch_04_img_2020.txt
# Moved label: batch_s02_img_135.txt
# Moved label: batch_s02_img_18.txt
# Moved image: batch_02_img_1140.jpg
# Moved image: batch_04_img_1780.jpg
# Moved image: BATCH_s05_img_1230.jpg
# Moved label: GOPR0027.txt
# Moved image: batch_02_img_20.jpg
# Moved image: batch_s02_img_138.jpg
# Moved label: batch_s02_img_15.txt
# Moved label: batch_s02_img_73.txt
# Moved label: batch_03_img_3740.txt
# Moved label: batch_02_img_1680.txt
# Moved image: BATCH_s05_img_5230.jpg
# Moved image: batch_01_frame_15.jpg
# Moved label: batch_05_img_3040.txt
# Moved image: GOPR0038.JPG
# Moved image: batch_s02_img_84.jpg
# Moved image: batch_s01_img_860.jpg
# Moved image: batch_04_img_4660.jpg
# Moved label: batch_02_img_2440.txt
# Moved image: batch_05_img_4040.jpg
# Moved image: batch_01_frame_27.jpg
# Moved label: BATCH_s04_img_1160.txt
# Moved label: batch_04_img_4080.txt
# Moved label: batch_02_img_1480.txt
# Moved image: batch_04_img_4540.jpg
# Moved image: batch_s02_img_32.jpg
# Moved image: batch_01_frame_19.jpg
# Moved image: BATCH_d07_img_3470.jpg
# Moved label: batch_05_img_3460.txt
# Moved label: batch_s02_img_10.txt
# Moved image: BATCH_s05_img_510.jpg
# Moved image: batch_s02_img_75.jpg
# Moved image: batch_s02_img_15.jpg
# Moved label: batch_04_img_4620.txt
# Moved image: BATCH_d08_img_4070.jpg
# Moved image: BATCH_d07_img_880.jpg
# Moved label: batch_05_img_4840.txt
# Moved image: batch_05_img_1500.jpg
# Moved image: GOPR0054.JPG
# Moved label: BATCH_d06_img_1640.txt
# Moved label: BATCH_d08_img_5120.txt
# Moved label: BATCH_s04_img_7240.txt
# Moved label: batch_s01_img_2580.txt
# Moved label: DJI_0010.txt
# Moved label: batch_s02_img_87.txt
# Moved label: BATCH_d07_img_600.txt
# Moved image: batch_01_frame_17.jpg
# Moved image: BATCH_d08_img_1510.jpg
# Moved label: BATCH_d07_img_610.txt
# Moved image: batch_01_frame_0.jpg
# Moved label: GOPR0053.txt
# Moved label: batch_s01_img_680.txt
# Moved label: batch_s02_img_4.txt
# Moved image: BATCH_s04_img_5900.jpg
# Moved label: BATCH_s04_img_9440.txt
# Moved label: batch_01_frame_23.txt
# Moved label: batch_04_img_840.txt
# Moved image: batch_03_img_1560.jpg
# Moved label: BATCH_d08_img_3950.txt
# Moved label: batch_04_img_1320.txt
# Moved image: BATCH_d08_img_4700.jpg
# Moved label: batch_s02_img_79.txt
# Moved image: batch_s02_img_50.jpg
# Moved image: batch_03_img_2920.jpg
# Moved image: batch_s02_img_144.jpg
# Moved image: batch_04_img_2300.jpg
# Moved image: batch_05_img_3460.jpg
# Moved image: batch_s01_img_2220.jpg
# Moved label: batch_s02_img_144.txt
# Moved image: batch_05_img_820.jpg
# Moved image: batch_s02_img_39.jpg
# Moved image: batch_s02_img_115.jpg
# Moved image: batch_01_frame_20.jpg
# Moved label: BATCH_d07_img_4760.txt
# Moved image: batch_01_frame_29.jpg
# Moved image: BATCH_s04_img_9200.jpg
# Moved label: batch_s01_img_2680.txt
# Moved image: BATCH_d07_img_3860.jpg
# Moved image: BATCH_s03_img_4220.jpg
# Moved image: batch_s01_img_2440.jpg
# Moved label: batch_05_img_4920.txt
# Moved image: batch_s01_img_1660.jpg
# Moved label: BATCH_d06_img_2360.txt
# Moved image: batch_05_img_4920.jpg
# Moved image: batch_01_frame_31.jpg
# Moved image: GOPR0021.JPG
# Moved label: BATCH_d07_img_6230.txt
# Moved image: BATCH_d08_img_1300.jpg
# Moved label: BATCH_d07_img_5020.txt
# Moved image: batch_s01_img_2360.jpg
# Moved label: BATCH_d07_img_4670.txt
# Moved label: BATCH_s04_img_6120.txt
# Moved image: BATCH_s04_img_3540.jpg
# Moved label: batch_04_img_980.txt
# Moved label: batch_s02_img_154.txt
# Moved label: BATCH_s04_img_9360.txt
# Moved image: batch_05_img_3580.jpg
# Moved image: batch_s02_img_41.jpg
# Moved image: batch_s02_img_10.jpg
# Moved image: BATCH_s04_img_9600.jpg
# Moved label: BATCH_d08_img_4420.txt
# Moved image: BATCH_s05_img_11130.jpg
# Moved label: GOPR0031.txt
# Moved label: batch_03_img_2160.txt
# Moved label: batch_04_img_1400.txt
# Moved label: GOPR0050.txt
# Moved image: batch_s02_img_20.jpg
# Moved image: batch_04_img_1260.jpg
# Moved label: batch_05_img_1980.txt
# Moved label: BATCH_d08_img_5050.txt
# Moved image: BATCH_s03_img_3640.jpg
# Moved image: batch_05_img_5540.jpg
# Moved label: GOPR0044.txt
# Moved label: BATCH_s04_img_8280.txt
# Moved label: batch_03_img_1920.txt
# Moved label: BATCH_s04_img_4160.txt
# Moved image: batch_s02_img_6.jpg
# Moved image: batch_s02_img_35.jpg
# Moved image: batch_s01_img_400.jpg
# Moved image: batch_05_img_260.jpg
# Moved label: BATCH_d08_img_5400.txt
# Moved image: batch_s02_img_33.jpg
# Moved image: batch_s02_img_152.jpg
# Moved label: BATCH_d06_img_1750.txt
# Moved label: GOPR0036.txt
# Moved label: batch_05_img_1160.txt
# Moved image: BATCH_s03_img_3340.jpg
# Moved image: BATCH_s04_img_5600.jpg
# Moved image: BATCH_d06_img_1640.jpg
# Moved image: batch_03_img_600.jpg
# Moved label: batch_s02_img_28.txt
# Moved label: BATCH_d07_img_1390.txt
# Moved image: batch_s02_img_8.jpg
# Moved image: BATCH_d06_img_2700.jpg
# Moved image: batch_04_img_1660.jpg
# Moved label: BATCH_d06_img_1270.txt
# Moved image: batch_s02_img_128.jpg
# Moved label: batch_03_img_1560.txt
# Moved image: batch_s02_img_52.jpg
# Moved image: GOPR0027.JPG
# Moved label: batch_04_img_1660.txt
# Moved image: batch_05_img_840.jpg
# Moved label: BATCH_d07_img_5780.txt
# Moved label: batch_s02_img_99.txt
# Moved label: batch_s02_img_91.txt
# Moved image: batch_s02_img_48.jpg
# Moved label: BATCH_s05_img_5740.txt
# Moved label: batch_s02_img_39.txt
# Moved image: batch_s02_img_101.jpg
# Moved image: batch_05_img_5200.jpg
# Moved label: BATCH_s03_img_800.txt
# Moved label: BATCH_s05_img_3790.txt
# Moved image: batch_s01_img_2680.jpg
# Moved label: BATCH_d07_img_360.txt
# Moved image: BATCH_s03_img_2300.jpg
# Moved label: batch_s02_img_107.txt
# Moved label: BATCH_s05_img_8800.txt
# Moved image: BATCH_s04_img_6060.jpg
# Moved label: batch_04_img_720.txt
# Moved image: BATCH_d07_img_5900.jpg
# Moved label: batch_s02_img_90.txt
# Moved image: batch_04_img_2140.jpg
# Moved image: BATCH_s05_img_3790.jpg
# Moved image: BATCH_s03_img_1320.jpg
# Moved image: BATCH_d08_img_1060.jpg
# Moved label: batch_s02_img_58.txt
# Moved label: BATCH_s05_img_3500.txt
# Moved label: batch_s02_img_118.txt
# Moved label: batch_s02_img_31.txt
# Moved image: batch_04_img_1320.jpg
# Moved label: batch_s02_img_149.txt
# Moved label: BATCH_d07_img_2500.txt
# Moved label: batch_03_img_2920.txt
# Moved label: BATCH_s05_img_6490.txt
# Moved label: batch_s02_img_59.txt
# Moved label: batch_s02_img_103.txt
# Moved label: BATCH_s05_img_3520.txt
# Moved label: BATCH_d07_img_4730.txt
# Moved image: BATCH_s05_img_7940.jpg
# Moved label: batch_04_img_1640.txt
# Moved image: BATCH_d07_img_1160.jpg
# Moved label: batch_04_img_1180.txt
# Moved image: batch_02_img_3820.jpg
# Moved image: batch_05_img_1160.jpg
# Moved label: batch_04_img_4540.txt
# Moved label: batch_03_img_2720.txt
# Moved label: BATCH_s05_img_7260.txt
# Moved label: BATCH_d07_img_410.txt
# Moved label: batch_01_frame_14.txt
# Moved label: batch_s02_img_132.txt
# Moved image: batch_02_img_360.jpg
# Moved label: batch_s01_img_620.txt
# Moved image: BATCH_s04_img_9360.jpg
# Moved image: BATCH_d07_img_2820.jpg
# Moved label: batch_s02_img_12.txt
# Moved image: BATCH_s05_img_6050.jpg
# Moved label: batch_s02_img_95.txt
# Moved image: batch_04_img_2780.jpg
# Moved image: batch_s02_img_9.jpg
# Moved label: GOPR0043.txt
# Moved label: batch_01_frame_18.txt
# Moved image: batch_01_frame_14.jpg
# Moved label: BATCH_d06_img_3340.txt
# Moved image: BATCH_d07_img_4720.jpg
# Moved image: BATCH_s03_img_1040.jpg
# Moved image: batch_s02_img_77.jpg
# Moved image: BATCH_d07_img_5780.jpg
# Moved image: batch_s02_img_0.jpg
# Moved image: batch_02_img_2000.jpg
# Moved label: BATCH_d07_img_6020.txt
# Moved image: BATCH_s03_img_840.jpg
# Moved label: BATCH_s04_img_3760.txt
# Moved label: batch_02_img_1320.txt
# Moved label: batch_s02_img_45.txt
# Moved image: BATCH_s05_img_3940.jpg
# Moved image: batch_04_img_1020.jpg
# Moved image: BATCH_d07_img_4430.jpg
# Moved label: batch_s01_img_400.txt
# Moved image: GOPR0056.JPG
# Moved image: BATCH_d07_img_5110.jpg
# Moved label: batch_s02_img_85.txt
# Moved label: GOPR0029.txt
# Moved image: GOPR0043.JPG
# Moved image: GOPR0055.JPG
# Moved image: batch_s02_img_145.jpg
# Moved label: BATCH_d07_img_5400.txt
# Moved image: BATCH_s03_img_800.jpg
# Moved label: batch_s02_img_50.txt
# Moved image: BATCH_d07_img_4880.jpg
# Moved image: GOPR0031.JPG
# Moved image: batch_05_img_1600.jpg
# Moved image: batch_04_img_3360.jpg
# Moved label: batch_s02_img_127.txt
# Moved label: batch_s02_img_66.txt
# Moved image: batch_s02_img_18.jpg
# Moved label: batch_s02_img_13.txt
# Moved image: BATCH_d08_img_1590.jpg
# Moved image: BATCH_s05_img_8800.jpg
# Moved image: batch_s02_img_28.jpg
# Moved label: batch_s02_img_34.txt
# Moved image: GOPR0019.JPG
# Moved label: batch_04_img_2080.txt
# Moved image: BATCH_s03_img_1400.jpg
# Moved image: BATCH_d06_img_0.jpg
# Moved label: BATCH_d07_img_2760.txt
# Moved label: BATCH_d07_img_2670.txt
# Moved image: batch_s02_img_141.jpg
# Moved label: BATCH_s03_img_3540.txt
# Moved image: BATCH_d07_img_3990.jpg
# Moved label: BATCH_s05_img_6050.txt
# Moved image: BATCH_s03_img_1640.jpg
# Moved label: BATCH_d06_img_2700.txt
# Moved label: batch_s01_img_2360.txt
# Moved image: BATCH_d07_img_4670.jpg
# Moved label: batch_03_img_3120.txt
# Moved label: BATCH_d07_img_320.txt
# Moved image: BATCH_d08_img_580.jpg
# Moved label: BATCH_s05_img_5990.txt
# Moved label: BATCH_s04_img_3600.txt
# Moved label: batch_04_img_2240.txt
# Moved image: batch_s02_img_3.jpg
# Moved label: batch_s02_img_14.txt
# Moved image: BATCH_s05_img_9220.jpg
# Moved image: batch_02_img_180.jpg
# Moved label: BATCH_s04_img_7660.txt
# Moved label: batch_04_img_1620.txt
# Moved label: batch_04_img_2900.txt
# Moved label: batch_s02_img_36.txt
# Moved label: BATCH_d06_img_3040.txt
# Moved label: BATCH_d07_img_5380.txt
# Moved label: batch_02_img_960.txt
# Moved label: batch_s02_img_22.txt
# Moved image: BATCH_s03_img_1000.jpg
# Moved label: BATCH_s03_img_1040.txt
# Moved label: batch_02_img_2800.txt
# Moved label: BATCH_s04_img_9200.txt
# Moved label: batch_05_img_5200.txt
# Moved image: BATCH_s04_img_6920.jpg
# Moved label: batch_s02_img_0.txt
# Moved image: batch_02_img_3580.jpg
# Moved image: BATCH_s04_img_4800.jpg
# Moved label: batch_03_img_720.txt
# Moved image: batch_s02_img_113.jpg
# Moved image: batch_s01_img_2780.jpg
# Moved label: BATCH_s03_img_3460.txt
# Moved image: batch_02_img_3500.jpg
# Moved label: batch_02_img_980.txt
# Moved label: batch_04_img_2140.txt
# Moved image: GOPR0029.JPG
# Moved label: batch_s02_img_134.txt
# Moved image: BATCH_s05_img_11050.jpg
# Moved label: BATCH_d08_img_580.txt
# Moved label: BATCH_d08_img_820.txt
# Moved label: batch_02_img_3400.txt
# Moved label: BATCH_d08_img_5300.txt
# Moved image: BATCH_s03_img_300.jpg
# Moved image: batch_s02_img_111.jpg
# Moved image: BATCH_s05_img_6490.jpg
# Moved label: batch_05_img_2960.txt
# Moved image: batch_s02_img_7.jpg
# Moved label: GOPR0033.txt
# Moved label: batch_s02_img_136.txt
# Moved label: BATCH_s05_img_6580.txt
# Moved image: batch_01_frame_25.jpg
# Moved image: BATCH_d07_img_360.jpg
# Moved label: batch_05_img_1820.txt
# Moved image: BATCH_s03_img_3460.jpg
# Moved image: batch_04_img_4300.jpg
# Moved image: BATCH_s04_img_1160.jpg
# Moved label: batch_03_img_660.txt
# Moved image: BATCH_d07_img_1120.jpg
# Moved image: BATCH_d06_img_3040.jpg
# Moved image: BATCH_d07_img_320.jpg
# Moved label: BATCH_s04_img_6920.txt
# Moved label: batch_04_img_3360.txt
# Moved label: batch_s02_img_101.txt
# Moved label: photo_2020-10-23_14-02-04.txt
# Moved label: batch_s02_img_89.txt
# Moved label: batch_04_img_3320.txt
# Moved label: batch_s01_img_460.txt
# Moved label: batch_05_img_4040.txt
# Moved image: BATCH_d07_img_6800.jpg
# Moved image: BATCH_d06_img_1660.jpg
# Moved label: batch_s02_img_140.txt
# Moved image: batch_02_img_1480.jpg
# Moved image: batch_s01_img_2800.jpg
# Moved image: BATCH_s05_img_2080.jpg
# Moved label: batch_s01_img_2800.txt
# Moved label: batch_s02_img_71.txt
# Moved image: batch_05_img_2960.jpg
# Moved label: batch_s02_img_35.txt
# Moved label: BATCH_d07_img_1650.txt
# Moved image: batch_s02_img_97.jpg
# Moved image: batch_01_frame_11.jpg
# Moved image: batch_04_img_4340.jpg
# Moved label: batch_s02_img_68.txt
# Moved label: BATCH_s04_img_4980.txt
# Moved label: BATCH_s04_img_8360.txt
# Moved label: batch_05_img_2220.txt
# Moved label: batch_s02_img_104.txt
# Moved label: batch_s02_img_21.txt
# Moved label: BATCH_d08_img_490.txt
# Moved image: BATCH_d08_img_2280.jpg
# Moved label: batch_02_img_2360.txt
# Moved image: batch_05_img_1620.jpg
# Moved image: BATCH_d08_img_710.jpg
# Moved image: batch_s02_img_70.jpg
# Moved label: BATCH_d08_img_2280.txt
# Moved label: batch_01_frame_3.txt
# Moved image: batch_05_img_3940.jpg
# Moved image: BATCH_s04_img_5840.jpg
# Moved image: BATCH_s03_img_3380.jpg
# Moved image: batch_03_img_1740.jpg
# Moved image: batch_05_img_1060.jpg
# Moved label: BATCH_d08_img_4340.txt
# Moved label: BATCH_d06_img_1500.txt
# Moved label: batch_s02_img_70.txt
# Moved image: BATCH_s04_img_4640.jpg
# Moved label: batch_04_img_2560.txt
# Moved label: BATCH_d07_img_3270.txt
# Moved label: batch_s02_img_26.txt
# Moved label: batch_05_img_4120.txt
# Moved label: BATCH_s04_img_5840.txt
# Moved label: BATCH_s04_img_5660.txt
# Moved image: BATCH_s03_img_1460.jpg
# Moved image: batch_s02_img_40.jpg
# Moved label: BATCH_d07_img_580.txt
# Moved image: batch_05_img_4120.jpg
# Moved image: batch_05_img_1080.jpg
# Moved image: batch_02_img_3060.jpg
# Moved image: BATCH_d07_img_2080.jpg
# Moved label: GOPR0030.txt
# Moved image: batch_s02_img_106.jpg
# Moved image: batch_04_img_4240.jpg
# Moved label: BATCH_s03_img_1100.txt
# Moved image: batch_04_img_3340.jpg
# Moved label: BATCH_d06_img_1390.txt
# Moved label: BATCH_d08_img_3190.txt
# Moved image: BATCH_d08_img_990.jpg
# Moved image: batch_02_img_3040.jpg
# Moved label: photo_2020-10-23_14-02-05.txt
# Moved label: batch_s02_img_24.txt
# Moved label: BATCH_d08_img_2810.txt
# Moved label: batch_01_frame_6.txt
# Moved image: BATCH_s05_img_9110.jpg
# Moved label: BATCH_d08_img_1210.txt
# Moved image: batch_s02_img_68.jpg
# Moved label: BATCH_s03_img_3200.txt
# Moved label: BATCH_s05_img_4250.txt
# Moved label: BATCH_d07_img_2600.txt
# Moved image: BATCH_d06_img_2320.jpg
# Moved image: GOPR0028.JPG
# Moved label: BATCH_s04_img_3400.txt
# Moved image: GOPR0049.JPG
# Moved label: batch_s02_img_88.txt
# Moved label: BATCH_d08_img_990.txt
# Moved label: BATCH_d07_img_4610.txt
# Moved image: batch_s02_img_86.jpg
# Moved label: BATCH_d07_img_650.txt
# Moved label: BATCH_s05_img_8070.txt
# Moved label: batch_05_img_1060.txt
# Moved label: batch_05_img_4460.txt
# Moved label: BATCH_d06_img_2320.txt
# Moved image: batch_01_frame_6.jpg
# Moved label: batch_01_frame_30.txt
# Moved label: batch_s01_img_1560.txt
# Moved image: BATCH_s03_img_1100.jpg
# Moved image: batch_04_img_3720.jpg
# Moved image: batch_01_frame_30.jpg
# Moved label: batch_03_img_1740.txt
# Moved image: BATCH_d07_img_6400.jpg
# Moved label: batch_s02_img_106.txt
# Moved label: batch_04_img_3080.txt
# Moved image: batch_01_frame_12.jpg
# Moved image: BATCH_s04_img_5660.jpg
# Moved label: BATCH_s04_img_4640.txt
# Moved label: batch_05_img_1720.txt
# Moved image: BATCH_d07_img_4610.jpg
# Moved label: batch_s02_img_151.txt
# Moved label: BATCH_d06_img_710.txt
# Moved label: batch_s02_img_51.txt
# Moved label: batch_02_img_3040.txt
# Moved label: batch_05_img_1080.txt
# Moved image: GOPR0047.JPG
# Moved label: batch_03_img_2100.txt
# Moved image: batch_01_frame_3.jpg
# Moved image: BATCH_s05_img_5660.jpg
# Moved image: GOPR0023.JPG
# Moved image: BATCH_d06_img_710.jpg
# Moved image: BATCH_s04_img_3400.jpg
# Moved label: batch_04_img_3340.txt
# Moved image: batch_05_img_4460.jpg
# Moved label: BATCH_d06_img_1440.txt
# Moved label: GOPR0046.txt
# Moved label: batch_s02_img_98.txt
# Moved image: BATCH_s03_img_3160.jpg
# Moved label: BATCH_d07_img_6400.txt
# Moved label: BATCH_d07_img_2720.txt
# Moved image: BATCH_d08_img_350.jpg
# Moved label: batch_05_img_3940.txt
# Moved label: BATCH_s03_img_1460.txt
# Moved image: BATCH_d08_img_2810.jpg
# Moved label: batch_01_frame_12.txt
# Moved image: batch_03_img_2100.jpg
# Moved image: batch_05_img_1720.jpg
# Moved label: batch_s02_img_67.txt
# Moved image: BATCH_s03_img_2220.jpg
# Moved image: batch_s02_img_55.jpg
# Moved image: batch_s02_img_25.jpg
# Moved label: batch_02_img_3640.txt
# Moved image: BATCH_d08_img_3190.jpg
# Moved image: batch_s01_img_1560.jpg
# Moved label: batch_s02_img_55.txt
# Moved image: batch_s01_img_2920.jpg
# Moved image: batch_05_img_2220.jpg
# Moved image: batch_s02_img_151.jpg
# Moved image: BATCH_d07_img_650.jpg
# Moved label: batch_s02_img_40.txt
# Moved label: batch_01_frame_2.txt
# Moved label: BATCH_d07_img_6940.txt
# Moved label: batch_s02_img_110.txt
# Moved image: BATCH_d07_img_2720.jpg
# Moved image: GOPR0039.JPG
# Moved image: batch_05_img_4500.jpg
# Moved label: GOPR0039.txt
# Moved label: batch_s02_img_121.txt
# Moved image: batch_04_img_2560.jpg
# Moved image: BATCH_s05_img_8070.jpg
# Moved label: batch_s01_img_980.txt
# Moved image: batch_04_img_260.jpg
# Moved label: GOPR0028.txt
# Moved image: BATCH_s03_img_3120.jpg
# Moved image: photo_2020-10-23_14-02-05.jpg
# Moved label: batch_03_img_2480.txt
# Moved image: camera_img_2.jpg
# Moved image: GOPR0046.JPG
# Moved label: batch_s01_img_2920.txt
# Moved label: batch_02_img_580.txt
# Moved label: BATCH_s05_img_9110.txt
# Moved label: batch_04_img_260.txt
# Moved image: BATCH_s03_img_3660.jpg
# Moved image: BATCH_d08_img_520.jpg
# Moved label: BATCH_s04_img_9300.txt
# Moved label: batch_04_img_4240.txt
# Moved image: batch_s02_img_24.jpg
# Moved image: batch_s02_img_88.jpg
# Moved image: BATCH_d07_img_2600.jpg
# Moved image: batch_s02_img_104.jpg
# Moved image: BATCH_s03_img_3200.jpg
# Moved image: BATCH_d06_img_1500.jpg
# Moved image: batch_s02_img_147.jpg
# Moved image: batch_05_img_5360.jpg
# Moved image: batch_s02_img_21.jpg
# Moved label: GOPR0049.txt
# Moved label: batch_03_img_820.txt
# Moved image: BATCH_d08_img_3000.jpg
# Moved image: batch_01_frame_5.jpg
# Moved label: BATCH_s03_img_2220.txt
# Moved image: BATCH_d08_img_1210.jpg
# Moved label: BATCH_s03_img_3120.txt
# Moved image: BATCH_s04_img_4980.jpg
# Moved image: BATCH_s04_img_8360.jpg
# Moved label: BATCH_d07_img_2080.txt
# Moved image: batch_s02_img_27.jpg
# Moved label: BATCH_d08_img_3000.txt
# Moved label: batch_01_frame_5.txt
# Moved image: BATCH_d06_img_1390.jpg
# Moved image: BATCH_d08_img_4150.jpg
# Moved label: batch_01_frame_33.txt
# Moved label: GOPR0052.txt
# Moved label: batch_04_img_3720.txt
# Moved label: GOPR0023.txt
# Moved image: GOPR0030.JPG
# Moved label: BATCH_d08_img_710.txt
# Moved label: BATCH_s03_img_660.txt
# Moved label: batch_s01_img_3100.txt
# Moved label: BATCH_d08_img_3090.txt
# Moved image: BATCH_d08_img_3090.jpg
# Moved image: BATCH_d08_img_490.jpg
# Moved image: batch_s02_img_51.jpg
# Moved image: batch_03_img_2480.jpg
# Moved image: batch_02_img_3640.jpg
# Moved label: BATCH_d08_img_4150.txt
# Moved image: batch_s02_img_26.jpg
# Moved image: batch_05_img_2180.jpg
# Moved label: BATCH_d07_img_6360.txt
# Moved label: BATCH_s03_img_3660.txt
# Moved label: batch_02_img_3060.txt
# Moved label: batch_s02_img_25.txt
# Moved image: batch_01_frame_33.jpg
# Moved image: batch_s01_img_980.jpg
# Moved label: batch_s02_img_86.txt
# Moved label: batch_s02_img_27.txt
# Moved label: BATCH_s05_img_5660.txt
# Moved label: BATCH_s03_img_3380.txt
# Moved image: batch_04_img_3080.jpg
# Moved image: BATCH_d07_img_6940.jpg
# Moved image: batch_s02_img_110.jpg
# Moved label: batch_05_img_1620.txt
# Moved label: batch_05_img_2180.txt
# Moved image: BATCH_d06_img_1440.jpg
# Moved label: batch_05_img_5360.txt
# Moved image: GOPR0052.JPG
# Moved image: batch_03_img_820.jpg
# Moved label: batch_s01_img_540.txt
# Moved label: camera_img_2.txt
# Moved label: GOPR0047.txt
# Moved image: BATCH_s03_img_660.jpg
# Moved image: batch_s01_img_3100.jpg
# Moved image: batch_s02_img_121.jpg
# Moved image: BATCH_s05_img_4250.jpg
# Moved label: batch_s02_img_147.txt
# Moved image: batch_s01_img_540.jpg
# Moved image: batch_s02_img_98.jpg
# Moved image: batch_02_img_580.jpg
# Moved label: BATCH_d08_img_520.txt
# Moved label: BATCH_s03_img_3160.txt
# Moved image: BATCH_d07_img_580.jpg
# Moved image: BATCH_s04_img_9300.jpg
# Moved image: batch_02_img_2360.jpg
# Moved image: BATCH_d07_img_6360.jpg
# Moved label: BATCH_d08_img_350.txt
# Moved image: batch_s02_img_67.jpg
# Moved image: batch_01_frame_2.jpg
# Moved image: BATCH_d07_img_3270.jpg
# Moved label: batch_05_img_4500.txt
# Moved image: BATCH_d08_img_4340.jpg
# Moved image: batch_02_img_3600.jpg
# Moved image: batch_04_img_1560.jpg
# Moved image: batch_s02_img_123.jpg
# Moved label: batch_01_frame_13.txt
# Moved label: batch_s01_img_2080.txt
# Moved image: BATCH_d07_img_6160.jpg
# Moved image: BATCH_d07_img_5980.jpg
# Moved label: batch_s02_img_148.txt
# Moved image: BATCH_d08_img_5470.jpg
# Moved label: BATCH_s04_img_3320.txt
# Moved label: batch_s02_img_53.txt
# Moved label: batch_s02_img_72.txt
# Moved image: batch_s02_img_53.jpg
# Moved label: BATCH_s04_img_5800.txt
# Moved image: batch_04_img_1520.jpg
# Moved label: BATCH_d07_img_6200.txt
# Moved label: batch_05_img_5620.txt
# Moved image: batch_s02_img_62.jpg
# Moved image: BATCH_s05_img_11210.jpg
# Moved image: batch_04_img_680.jpg
# Moved image: BATCH_s04_img_8440.jpg
# Moved image: batch_s02_img_29.jpg
# Moved image: batch_05_img_4340.jpg
# Moved label: batch_01_frame_8.txt
# Moved label: photo_2020-10-23_14-02-01.txt
# Moved label: BATCH_s04_img_7820.txt
# Moved label: batch_02_img_1560.txt
# Moved image: batch_s02_img_109.jpg
# Moved label: batch_05_img_5980.txt
# Moved label: batch_s02_img_137.txt
# Moved label: BATCH_d07_img_2930.txt
# Moved label: BATCH_d07_img_6160.txt
# Moved image: BATCH_d07_img_3380.jpg
# Moved image: batch_03_img_3340.jpg
# Moved image: batch_04_img_4400.jpg
# Moved label: batch_s01_img_2300.txt
# Moved label: batch_01_frame_4.txt
# Moved label: BATCH_s03_img_3040.txt
# Moved image: BATCH_s05_img_8100.jpg
# Moved label: batch_s02_img_105.txt
# Moved image: BATCH_d08_img_1760.jpg
# Moved image: batch_s02_img_57.jpg
# Moved image: BATCH_s03_img_3040.jpg
# Moved label: BATCH_d07_img_5210.txt
# Moved image: BATCH_d06_img_1790.jpg
# Moved image: BATCH_s04_img_7720.jpg
# Moved label: batch_s02_img_46.txt
# Moved label: batch_s02_img_42.txt
# Moved image: BATCH_s04_img_9740.jpg
# Moved label: batch_s02_img_119.txt
# Moved label: batch_s02_img_38.txt
# Moved label: batch_05_img_4340.txt
# Moved label: BATCH_s05_img_8100.txt
# Moved image: batch_05_img_5980.jpg
# Moved label: BATCH_s03_img_380.txt
# Moved image: BATCH_s04_img_1240.jpg
# Moved image: batch_s02_img_133.jpg
# Moved image: batch_04_img_4580.jpg
# Moved image: BATCH_d08_img_440.jpg
# Moved image: batch_02_img_3700.jpg
# Moved label: BATCH_s04_img_9840.txt
# Moved image: BATCH_s04_img_3320.jpg
# Moved label: batch_s02_img_109.txt
# Moved label: BATCH_d07_img_5980.txt
# Moved image: batch_s02_img_42.jpg
# Moved image: batch_05_img_4240.jpg
# Moved image: batch_s01_img_1440.jpg
# Moved label: batch_s02_img_62.txt
# Moved image: batch_01_frame_28.jpg
# Moved image: batch_01_frame_8.jpg
# Moved label: BATCH_d07_img_6740.txt
# Moved image: batch_s02_img_72.jpg
# Moved label: BATCH_d08_img_4460.txt
# Moved image: BATCH_s04_img_7820.jpg
# Moved label: BATCH_d06_img_2400.txt
# Moved label: batch_s02_img_123.txt
# Moved image: GOPR0037.JPG
# Moved label: GOPR0032.txt
# Moved image: batch_02_img_860.jpg
# Moved label: BATCH_s04_img_7800.txt
# Moved label: BATCH_d06_img_3220.txt
# Moved label: BATCH_d08_img_1760.txt
# Moved label: BATCH_s04_img_8080.txt
# Moved label: BATCH_s04_img_8440.txt
# Moved image: BATCH_d07_img_2310.jpg
# Moved label: batch_s02_img_43.txt
# Moved image: BATCH_s04_img_6560.jpg
# Moved label: batch_03_img_3340.txt
# Moved image: batch_s02_img_46.jpg
# Moved image: BATCH_s04_img_8080.jpg
# Moved label: batch_s02_img_29.txt
# Moved label: GOPR0035.txt
# Moved image: BATCH_s03_img_380.jpg
# Moved label: BATCH_d08_img_4050.txt
# Moved label: GOPR0042.txt
# Moved image: BATCH_d06_img_2400.jpg
# Moved image: GOPR0035.JPG
# Moved image: BATCH_s03_img_540.jpg
# Moved label: BATCH_d08_img_5470.txt
# Moved label: BATCH_s05_img_2630.txt
# Moved label: batch_03_img_1280.txt
# Moved label: BATCH_s05_img_3590.txt
# Moved image: BATCH_d07_img_2930.jpg
# Moved label: BATCH_d08_img_2210.txt
# Moved label: batch_s02_img_133.txt
# Moved image: batch_s02_img_1.jpg
# Moved image: batch_03_img_3020.jpg
# Moved image: batch_02_img_1560.jpg
# Moved image: BATCH_d06_img_2500.jpg
# Moved label: batch_s01_img_1440.txt
# Moved image: BATCH_d07_img_5210.jpg
# Moved image: BATCH_d08_img_2640.jpg
# Moved image: batch_05_img_5620.jpg
# Moved label: batch_03_img_3020.txt
# Moved label: batch_02_img_860.txt
# Moved image: batch_05_img_2040.jpg
# Moved image: BATCH_s05_img_2630.jpg
# Moved label: batch_s02_img_153.txt
# Moved image: BATCH_d08_img_2210.jpg
# Moved image: BATCH_d07_img_2380.jpg
# Moved label: batch_s02_img_49.txt
# Moved image: photo_2020-10-23_14-02-01.jpg
# Moved label: batch_04_img_1520.txt
# Moved label: batch_02_img_3600.txt
# Moved label: batch_02_img_1240.txt
# Moved image: camera_img_3.jpg
# Moved label: batch_s02_img_37.txt
# Moved image: BATCH_d06_img_3220.jpg
# Moved image: batch_s02_img_124.jpg
# Moved image: batch_s02_img_130.jpg
# Moved label: GOPR0051.txt
# Moved label: BATCH_d07_img_2380.txt
# Moved image: BATCH_s04_img_1080.jpg
# Moved image: BATCH_d07_img_6740.jpg
# Moved image: BATCH_s04_img_9840.jpg
# Moved image: batch_s02_img_153.jpg
# Moved label: BATCH_s05_img_1260.txt
# Moved image: batch_04_img_3180.jpg
# Moved label: batch_01_frame_21.txt
# Moved label: BATCH_s04_img_9740.txt
# Moved label: BATCH_s04_img_7720.txt
# Moved label: BATCH_d07_img_2310.txt
# Moved label: BATCH_d07_img_6110.txt
# Moved label: batch_04_img_4580.txt
# Moved image: batch_s02_img_105.jpg
# Moved image: batch_01_frame_13.jpg
# Moved image: BATCH_d07_img_2420.jpg
# Moved label: BATCH_s05_img_7600.txt
# Moved label: batch_01_frame_16.txt
# Moved image: batch_s02_img_38.jpg
# Moved image: batch_s02_img_49.jpg
# Moved label: batch_s02_img_17.txt
# Moved image: batch_s02_img_47.jpg
# Moved image: BATCH_s05_img_7600.jpg
# Moved image: BATCH_d08_img_4050.jpg
# Moved label: batch_05_img_5880.txt
# Moved image: BATCH_s04_img_7800.jpg
# Moved label: batch_01_frame_28.txt
# Moved label: batch_04_img_3180.txt
# Moved label: batch_05_img_4240.txt
# Moved image: batch_s02_img_37.jpg
# Moved label: BATCH_d06_img_1790.txt
# Moved image: BATCH_d07_img_6200.jpg
# Moved label: batch_04_img_3680.txt
# Moved label: batch_02_img_2960.txt
# Moved label: batch_04_img_3400.txt
# Moved label: BATCH_s04_img_1080.txt
# Moved image: BATCH_d08_img_4460.jpg
# Moved label: batch_05_img_1440.txt
# Moved label: batch_s02_img_47.txt
# Moved label: BATCH_d07_img_2420.txt
# Moved label: batch_s02_img_130.txt
# Moved image: batch_02_img_1240.jpg
# Moved image: batch_s02_img_148.jpg
# Moved image: batch_04_img_3400.jpg
# Moved image: batch_05_img_5880.jpg
# Moved label: BATCH_d06_img_3120.txt
# Moved image: batch_s01_img_2300.jpg
# Moved image: BATCH_s05_img_3590.jpg
# Moved image: GOPR0051.JPG
# Moved image: BATCH_s04_img_5800.jpg
# Moved label: BATCH_d06_img_2500.txt
# Moved label: batch_s02_img_124.txt
# Moved label: batch_02_img_3700.txt
# Moved label: BATCH_d08_img_440.txt
# Moved image: batch_01_frame_4.jpg
# Moved label: batch_04_img_680.txt
# Moved label: BATCH_s04_img_6560.txt
# Moved image: batch_s02_img_119.jpg
# Moved image: BATCH_d06_img_3120.jpg
# Moved image: batch_s02_img_17.jpg
# Moved label: batch_04_img_1560.txt
# Moved image: camera_img_1.jpg
# Moved image: batch_02_img_2960.jpg
# Moved image: BATCH_s05_img_1260.jpg
# Moved image: batch_s02_img_122.jpg
# Moved image: batch_04_img_4480.jpg
# Moved image: batch_s02_img_117.jpg
# Moved label: GOPR0037.txt
# Moved label: BATCH_d07_img_3380.txt
# Moved image: GOPR0032.JPG
# Moved label: batch_s02_img_122.txt
# Moved image: BATCH_d07_img_6110.jpg
# Moved label: BATCH_s03_img_540.txt
# Moved label: batch_s02_img_1.txt
# Moved image: batch_04_img_3680.jpg
# Moved image: batch_05_img_1440.jpg
# Moved label: batch_05_img_2040.txt
# Moved label: batch_s02_img_61.txt
# Moved label: camera_img_3.txt
# Moved label: BATCH_d08_img_2640.txt
# Moved image: batch_03_img_3380.jpg
# Moved label: BATCH_s05_img_11210.txt
# Moved label: batch_04_img_4480.txt
# Moved image: batch_s02_img_61.jpg
# Moved image: batch_03_img_1280.jpg
# Moved label: batch_s02_img_117.txt
# Moved image: batch_01_frame_21.jpg
# Moved image: BATCH_d06_img_130.jpg
# Moved label: BATCH_s04_img_1240.txt
# Moved label: BATCH_d07_img_3010.txt
# Moved label: batch_s02_img_57.txt
# Moved image: batch_s02_img_43.jpg
# Moved label: camera_img_1.txt
# Moved label: batch_04_img_4400.txt
# Moved image: BATCH_d07_img_3010.jpg
# Moved image: batch_s01_img_2080.jpg
# Moved label: batch_03_img_3380.txt
# Moved image: batch_01_frame_16.jpg
# Moved image: GOPR0042.JPG
# Moved image: batch_s02_img_137.jpg
# Moved label: BATCH_d06_img_130.txt

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc
# !python /content/train_val_split.py --datapath="/content/data" --train_pct=0.9
# Out:
# --2025-03-31 19:21:43--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/plain]
# Saving to: ‘/content/train_val_split.py’
#
# /content/train_val_ 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2025-03-31 19:21:43 (41.4 MB/s) - ‘/content/train_val_split.py’ saved [3203/3203]
#
# Created folder at /content/UAVVaste/data/train/images.
# Created folder at /content/UAVVaste/data/train/labels.
# Created folder at /content/UAVVaste/data/validation/images.
# Created folder at /content/UAVVaste/data/validation/labels.
# Number of image files: 772
# Number of annotation files: 772
# Images moving to train: 694
# Images moving to validation: 78

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.99-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.99-py3-none-any.whl (976 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.9/976.9 kB 51.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.99 ultralytics-thop-2.0.14

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/UAVVaste/data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/UAVVaste/data/classes.txt'
path_to_data_yaml = '/content/UAVVaste/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/UAVVaste/data.yaml
# Out:
# Created config file at /content/UAVVaste/data.yaml
#
# File contents:
#
# path: /content/UAVVaste/data
# train: train/images
# val: validation/images
# nc: 1
# names:
# - '0'

# %%
# !yolo detect train data=/content/UAVVaste/data.yaml model=yolo11s.pt epochs=100 imgsz=640 patience=70 resume=True
# Out:
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11s.pt, data=/content/UAVVaste/data.yaml, epochs=70, time=None, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 121MB/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743449078.706738    5378 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743449078.774407    5378 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,179 parameters, 9,428,163 gradients, 21.5 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 241MB/s]
# AMP: checks passed ✅
# train: Scanning /content/UAVVaste/data/train/labels... 694 images, 0 backgrounds, 1 corrupt: 100% 694/694 [00:01<00:00, 400.62it/s]
# train: WARNING ⚠️ /content/UAVVaste/data/train/images/GOPR0047.JPG: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0608]
# train: New cache created: /content/UAVVaste/data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/UAVVaste/data/validation/labels... 78 images, 0 backgrounds, 1 corrupt: 100% 78/78 [00:00<00:00, 317.12it/s]
# val: WARNING ⚠️ /content/UAVVaste/data/validation/images/GOPR0052.JPG: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2402]
# val: New cache created: /content/UAVVaste/data/validation/labels.cache
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 70 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1
00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.71it/s]
#                    all         77        401      0.814      0.701      0.743      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/70      7.88G      1.183     0.6489     0.8659         13        640: 100% 44/44 [00:53<00:00,  1.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.61it/s]
#                    all         77        401      0.859      0.648      0.736      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/70      7.92G      1.171     0.6301     0.8658         17        640: 100% 44/44 [00:54<00:00,  1.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.06it/s]
#                    all         77        401      0.852      0.671       0.75      0.422
#
# 70 epochs completed in 1.076 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 19.2MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 19.2MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:03<00:00,  1.27s/it]
#                    all         77        401      0.865      0.686      0.765      0.431
# Speed: 0.2ms preprocess, 3.9ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo detect predict model=runs/detect/train2/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/78 /content/UAVVaste/data/validation/images/BATCH_d06_img_0.jpg: 384x640 3 0s, 69.1ms
# image 2/78 /content/UAVVaste/data/validation/images/BATCH_d06_img_130.jpg: 384x640 4 0s, 12.1ms
# image 3/78 /content/UAVVaste/data/validation/images/BATCH_d06_img_1790.jpg: 384x640 2 0s, 17.0ms
# image 4/78 /content/UAVVaste/data/validation/images/BATCH_d06_img_2540.jpg: 384x640 4 0s, 18.4ms
# image 5/78 /content/UAVVaste/data/validation/images/BATCH_d06_img_3100.jpg: 384x640 6 0s, 17.0ms
# image 6/78 /content/UAVVaste/data/validation/images/BATCH_d07_img_1010.jpg: 384x640 1 0, 14.8ms
# image 7/78 /content/UAVVaste/data/validation/images/BATCH_d07_img_1330.jpg: 384x640 4 0s, 10.9ms
# image 8/78 /content/UAVVaste/data/validation/images/BATCH_d07_img_1650.jpg: 384x640 10 0s, 10.9ms
# image 9/78 /content/UAVVaste/data/validation/images/BATCH_d07_img_4610.jpg: 384x640 4 0s, 10.9ms
# image 10/78 /content/UAVVaste/data/validation/images/BATCH_d07_img_510.jpg: 384x640 6 0s, 10.9ms
# image 11/78 /content/UAVVaste/data/validation/images/BATCH_d07_img_5980.jpg: 384x640 4 0s, 10.9ms
# image 12/78 /content/UAVVaste/data/validation/images/BATCH_d07_img_610.jpg: 384x640 8 0s, 10.9ms
# image 13/78 /content/UAVVaste/data/validation/images/BATCH_d07_img_650.jpg: 384x640 7 0s, 10.9ms
# image 14/78 /content/UAVVaste/data/validation/images/BATCH_d08_img_1060.jpg: 384x640 5 0s, 10.9ms
# image 15/78 /content/UAVVaste/data/validation/images/BATCH_d08_img_2280.jpg: 384x640 3 0s, 10.9ms
# image 16/78 /content/UAVVaste/data/validation/images/BATCH_d08_img_2500.jpg: 384x640 1 0, 10.8ms
# image 17/78 /content/UAVVaste/data/validation/images/BATCH_d08_img_2580.jpg: 384x640 2 0s, 10.9ms
# image 18/78 /content/UAVVaste/data/validation/images/BATCH_d08_img_5470.jpg: 384x640 6 0s, 10.9ms
# image 19/78 /content/UAVVaste/data/validation/images/BATCH_s03_img_2160.jpg: 288x640 8 0s, 49.8ms
# image 20/78 /content/UAVVaste/data/validation/images/BATCH_s03_img_3360.jpg: 288x640 11 0s, 10.8ms
# image 21/78 /content/UAVVaste/data/validation/images/BATCH_s03_img_3420.jpg: 288x640 5 0s, 10.4ms
# image 22/78 /content/UAVVaste/data/validation/images/BATCH_s03_img_3920.jpg: 288x640 5 0s, 10.4ms
